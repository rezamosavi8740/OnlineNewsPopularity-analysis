# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math
from sklearn.preprocessing import QuantileTransformer
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
data = pd.read_csv("OnlineNewsPopularity.csv")
data.head()
# Out:
#                                                  url   timedelta  \
# 0  http://mashable.com/2013/01/07/amazon-instant-...       731.0
# 1  http://mashable.com/2013/01/07/ap-samsung-spon...       731.0
# 2  http://mashable.com/2013/01/07/apple-40-billio...       731.0
# 3  http://mashable.com/2013/01/07/astronaut-notre...       731.0
# 4   http://mashable.com/2013/01/07/att-u-verse-apps/       731.0
#
#     n_tokens_title   n_tokens_content   n_unique_tokens   n_non_stop_words  \
# 0             12.0              219.0          0.663594                1.0
# 1              9.0              255.0          0.604743                1.0
# 2              9.0              211.0          0.575130                1.0
# 3              9.0              531.0          0.503788                1.0
# 4             13.0             1072.0          0.415646                1.0
#
#     n_non_stop_unique_tokens   num_hrefs   num_self_hrefs   num_imgs  ...  \
# 0                   0.815385         4.0              2.0        1.0  ...
# 1                   0.791946         3.0              1.0        1.0  ...
# 2                   0.663866         3.0              1.0        1.0  ...
# 3                   0.665635         9.0              0.0        1.0  ...
# 4                   0.540890        19.0             19.0       20.0  ...
#
#     min_positive_polarity   max_positive_polarity   avg_negative_polarity  \
# 0                0.100000                     0.7               -0.350000
# 1                0.033333                     0.7               -0.118750
# 2                0.100000                     1.0               -0.466667
# 3                0.136364                     0.8               -0.369697
# 4                0.033333                     1.0               -0.220192
#
#     min_negative_polarity   max_negative_polarity   title_subjectivity  \
# 0                  -0.600               -0.200000             0.500000
# 1                  -0.125               -0.100000             0.000000
# 2                  -0.800               -0.133333             0.000000
# 3                  -0.600               -0.166667             0.000000
# 4                  -0.500               -0.050000             0.454545
#
#     title_sentiment_polarity   abs_title_subjectivity  \
# 0                  -0.187500                 0.000000
# 1                   0.000000                 0.500000
# 2                   0.000000                 0.500000
# 3                   0.000000                 0.500000
# 4                   0.136364                 0.045455
#
#     abs_title_sentiment_polarity   shares
# 0                       0.187500      593
# 1                       0.000000      711
# 2                       0.000000     1500
# 3                       0.000000     1200
# 4                       0.136364      505
#
# [5 rows x 61 columns]

# %%
data.shape
# Out:
# (39644, 61)

# %%
data.isna().sum()
# Out:
# url                              0
#  timedelta                       0
#  n_tokens_title                  0
#  n_tokens_content                0
#  n_unique_tokens                 0
#                                 ..
#  title_subjectivity              0
#  title_sentiment_polarity        0
#  abs_title_subjectivity          0
#  abs_title_sentiment_polarity    0
#  shares                          0
# Length: 61, dtype: int64

# %%
data.describe()
# Out:
#           timedelta   n_tokens_title   n_tokens_content   n_unique_tokens  \
# count  39644.000000     39644.000000       39644.000000      39644.000000
# mean     354.530471        10.398749         546.514731          0.548216
# std      214.163767         2.114037         471.107508          3.520708
# min        8.000000         2.000000           0.000000          0.000000
# 25%      164.000000         9.000000         246.000000          0.470870
# 50%      339.000000        10.000000         409.000000          0.539226
# 75%      542.000000        12.000000         716.000000          0.608696
# max      731.000000        23.000000        8474.000000        701.000000
#
#         n_non_stop_words   n_non_stop_unique_tokens     num_hrefs  \
# count       39644.000000               39644.000000  39644.000000
# mean            0.996469                   0.689175     10.883690
# std             5.231231                   3.264816     11.332017
# min             0.000000                   0.000000      0.000000
# 25%             1.000000                   0.625739      4.000000
# 50%             1.000000                   0.690476      8.000000
# 75%             1.000000                   0.754630     14.000000
# max          1042.000000                 650.000000    304.000000
#
#         num_self_hrefs      num_imgs    num_videos  ...  \
# count     39644.000000  39644.000000  39644.000000  ...
# mean          3.293638      4.544143      1.249874  ...
# std           3.855141      8.309434      4.107855  ...
# min           0.000000      0.000000      0.000000  ...
# 25%           1.000000      1.000000      0.000000  ...
# 50%           3.000000      1.000000      0.000000  ...
# 75%           4.000000      4.000000      1.000000  ...
# max         116.000000    128.000000     91.000000  ...
#
#         min_positive_polarity   max_positive_polarity   avg_negative_polarity  \
# count            39644.000000            39644.000000            39644.000000
# mean                 0.095446                0.756728               -0.259524
# std                  0.071315                0.247786                0.127726
# min                  0.000000                0.000000               -1.000000
# 25%                  0.050000                0.600000               -0.328383
# 50%                  0.100000                0.800000               -0.253333
# 75%                  0.100000                1.000000               -0.186905
# max                  1.000000                1.000000                0.000000
#
#         min_negative_polarity   max_negative_polarity   title_subjectivity  \
# count            39644.000000            39644.000000         39644.000000
# mean                -0.521944               -0.107500             0.282353
# std                  0.290290                0.095373             0.324247
# min                 -1.000000               -1.000000             0.000000
# 25%                 -0.700000               -0.125000             0.000000
# 50%                 -0.500000               -0.100000             0.150000
# 75%                 -0.300000               -0.050000             0.500000
# max                  0.000000                0.000000             1.000000
#
#         title_sentiment_polarity   abs_title_subjectivity  \
# count               39644.000000             39644.000000
# mean                    0.071425                 0.341843
# std                     0.265450                 0.188791
# min                    -1.000000                 0.000000
# 25%                     0.000000                 0.166667
# 50%                     0.000000                 0.500000
# 75%                     0.150000                 0.500000
# max                     1.000000                 0.500000
#
#         abs_title_sentiment_polarity         shares
# count                   39644.000000   39644.000000
# mean                        0.156064    3395.380184
# std                         0.226294   11626.950749
# min                         0.000000       1.000000
# 25%                         0.000000     946.000000
# 50%                         0.000000    1400.000000
# 75%                         0.250000    2800.000000
# max                         1.000000  843300.000000
#
# [8 rows x 60 columns]

# %%
data.drop(columns = ['url'] ,inplace=True)
data.head(10)
# Out:
#     timedelta   n_tokens_title   n_tokens_content   n_unique_tokens  \
# 0       731.0             12.0              219.0          0.663594
# 1       731.0              9.0              255.0          0.604743
# 2       731.0              9.0              211.0          0.575130
# 3       731.0              9.0              531.0          0.503788
# 4       731.0             13.0             1072.0          0.415646
# 5       731.0             10.0              370.0          0.559889
# 6       731.0              8.0              960.0          0.418163
# 7       731.0             12.0              989.0          0.433574
# 8       731.0             11.0               97.0          0.670103
# 9       731.0             10.0              231.0          0.636364
#
#     n_non_stop_words   n_non_stop_unique_tokens   num_hrefs   num_self_hrefs  \
# 0                1.0                   0.815385         4.0              2.0
# 1                1.0                   0.791946         3.0              1.0
# 2                1.0                   0.663866         3.0              1.0
# 3                1.0                   0.665635         9.0              0.0
# 4                1.0                   0.540890        19.0             19.0
# 5                1.0                   0.698198         2.0              2.0
# 6                1.0                   0.549834        21.0             20.0
# 7                1.0                   0.572108        20.0             20.0
# 8                1.0                   0.836735         2.0              0.0
# 9                1.0                   0.797101         4.0              1.0
#
#     num_imgs   num_videos  ...   min_positive_polarity  \
# 0        1.0          0.0  ...                0.100000
# 1        1.0          0.0  ...                0.033333
# 2        1.0          0.0  ...                0.100000
# 3        1.0          0.0  ...                0.136364
# 4       20.0          0.0  ...                0.033333
# 5        0.0          0.0  ...                0.136364
# 6       20.0          0.0  ...                0.100000
# 7       20.0          0.0  ...                0.100000
# 8        0.0          0.0  ...                0.400000
# 9        1.0          1.0  ...                0.100000
#
#     max_positive_polarity   avg_negative_polarity   min_negative_polarity  \
# 0                     0.7               -0.350000                  -0.600
# 1                     0.7               -0.118750                  -0.125
# 2                     1.0               -0.466667                  -0.800
# 3                     0.8               -0.369697                  -0.600
# 4                     1.0               -0.220192                  -0.500
# 5                     0.6               -0.195000                  -0.400
# 6                     1.0               -0.224479                  -0.500
# 7                     1.0               -0.242778                  -0.500
# 8                     0.8               -0.125000                  -0.125
# 9                     0.5               -0.238095                  -0.500
#
#     max_negative_polarity   title_subjectivity   title_sentiment_polarity  \
# 0               -0.200000             0.500000                  -0.187500
# 1               -0.100000             0.000000                   0.000000
# 2               -0.133333             0.000000                   0.000000
# 3               -0.166667             0.000000                   0.000000
# 4               -0.050000             0.454545                   0.136364
# 5               -0.100000             0.642857                   0.214286
# 6               -0.050000             0.000000                   0.000000
# 7               -0.050000             1.000000                   0.500000
# 8               -0.125000             0.125000                   0.000000
# 9               -0.100000             0.000000                   0.000000
#
#     abs_title_subjectivity   abs_title_sentiment_polarity   shares
# 0                 0.000000                       0.187500      593
# 1                 0.500000                       0.000000      711
# 2                 0.500000                       0.000000     1500
# 3                 0.500000                       0.000000     1200
# 4                 0.045455                       0.136364      505
# 5                 0.142857                       0.214286      855
# 6                 0.500000                       0.000000      556
# 7                 0.500000                       0.500000      891
# 8                 0.375000                       0.000000     3600
# 9                 0.500000                       0.000000      710
#
# [10 rows x 60 columns]

# %%
data.hist(figsize=(20,20))
plt.show()

# %% [markdown]
# # chck correlation

# %%
cor=data.corr()
plt.figure(figsize=(15,15))
df_lt = cor.where(np.tril(np.ones(cor.shape)).astype(np.bool))
sns.heatmap(df_lt,cmap='Blues')
# Out:
# /var/folders/nb/s2fx_kf54nv8fpngr1jppkjh0000gn/T/ipykernel_10633/2963683346.py:3: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   df_lt = cor.where(np.tril(np.ones(cor.shape)).astype(np.bool))
# <AxesSubplot:>

# %%
cor.head(10)
# Out:
#                             timedelta   n_tokens_title   n_tokens_content  \
#  timedelta                   1.000000        -0.240320          -0.062867
#  n_tokens_title             -0.240320         1.000000           0.018160
#  n_tokens_content           -0.062867         0.018160           1.000000
#  n_unique_tokens             0.002866        -0.005318          -0.004737
#  n_non_stop_words            0.000089        -0.004754           0.017512
#  n_non_stop_unique_tokens    0.003805        -0.005420           0.000373
#  num_hrefs                  -0.000832        -0.053496           0.423065
#  num_self_hrefs              0.064530        -0.014856           0.304682
#  num_imgs                   -0.027636        -0.008858           0.342600
#  num_videos                  0.000936         0.051460           0.103699
#
#                             n_unique_tokens   n_non_stop_words  \
#  timedelta                         0.002866           0.000089
#  n_tokens_title                   -0.005318          -0.004754
#  n_tokens_content                 -0.004737           0.017512
#  n_unique_tokens                   1.000000           0.999572
#  n_non_stop_words                  0.999572           1.000000
#  n_non_stop_unique_tokens          0.999852           0.999532
#  num_hrefs                        -0.004352           0.005521
#  num_self_hrefs                    0.006620           0.013598
#  num_imgs                          0.018802           0.028486
#  num_videos                       -0.000597          -0.000899
#
#                             n_non_stop_unique_tokens   num_hrefs  \
#  timedelta                                  0.003805   -0.000832
#  n_tokens_title                            -0.005420   -0.053496
#  n_tokens_content                           0.000373    0.423065
#  n_unique_tokens                            0.999852   -0.004352
#  n_non_stop_words                           0.999532    0.005521
#  n_non_stop_unique_tokens                   1.000000   -0.004983
#  num_hrefs                                 -0.004983    1.000000
#  num_self_hrefs                             0.007584    0.396452
#  num_imgs                                   0.014230    0.342633
#  num_videos                                -0.000963    0.114518
#
#                             num_self_hrefs   num_imgs   num_videos  ...  \
#  timedelta                        0.064530  -0.027636     0.000936  ...
#  n_tokens_title                  -0.014856  -0.008858     0.051460  ...
#  n_tokens_content                 0.304682   0.342600     0.103699  ...
#  n_unique_tokens                  0.006620   0.018802    -0.000597  ...
#  n_non_stop_words                 0.013598   0.028486    -0.000899  ...
#  n_non_stop_unique_tokens         0.007584   0.014230    -0.000963  ...
#  num_hrefs                        0.396452   0.342633     0.114518  ...
#  num_self_hrefs                   1.000000   0.238586     0.077458  ...
#  num_imgs                         0.238586   1.000000    -0.067336  ...
#  num_videos                       0.077458  -0.067336     1.000000  ...
#
#                             min_positive_polarity   max_positive_polarity  \
#  timedelta                               0.054772                0.098288
#  n_tokens_title                         -0.025069               -0.021662
#  n_tokens_content                       -0.261493                0.415706
#  n_unique_tokens                         0.009193               -0.009054
#  n_non_stop_words                        0.000904                0.002062
#  n_non_stop_unique_tokens                0.008380               -0.002245
#  num_hrefs                              -0.082168                0.286733
#  num_self_hrefs                         -0.072648                0.189922
#  num_imgs                               -0.024683                0.155232
#  num_videos                             -0.010103                0.125659
#
#                             avg_negative_polarity   min_negative_polarity  \
#  timedelta                              -0.000507                0.062175
#  n_tokens_title                         -0.017096               -0.029146
#  n_tokens_content                       -0.130375               -0.450603
#  n_unique_tokens                         0.001453                0.009902
#  n_non_stop_words                       -0.001372               -0.001214
#  n_non_stop_unique_tokens               -0.001972                0.004318
#  num_hrefs                              -0.152146               -0.263576
#  num_self_hrefs                         -0.058222               -0.122071
#  num_imgs                               -0.072500               -0.136522
#  num_videos                             -0.115976               -0.138190
#
#                             max_negative_polarity   title_subjectivity  \
#  timedelta                              -0.063239            -0.015919
#  n_tokens_title                          0.011425             0.077245
#  n_tokens_content                        0.225870             0.004484
#  n_unique_tokens                        -0.007315            -0.004678
#  n_non_stop_words                       -0.000761            -0.005389
#  n_non_stop_unique_tokens               -0.006708            -0.005860
#  num_hrefs                               0.054948             0.043950
#  num_self_hrefs                          0.039153            -0.011239
#  num_imgs                                0.042644             0.056815
#  num_videos                              0.027251             0.061028
#
#                             title_sentiment_polarity   abs_title_subjectivity  \
#  timedelta                                  0.038711                 0.011551
#  n_tokens_title                             0.000240                -0.146954
#  n_tokens_content                           0.023358                 0.007136
#  n_unique_tokens                           -0.002333                -0.009242
#  n_non_stop_words                          -0.001650                -0.008511
#  n_non_stop_unique_tokens                  -0.002910                -0.008572
#  num_hrefs                                  0.039041                 0.009443
#  num_self_hrefs                             0.026224                 0.008961
#  num_imgs                                   0.046310                -0.013759
#  num_videos                                 0.021980                -0.021982
#
#                             abs_title_sentiment_polarity    shares
#  timedelta                                     -0.002745  0.008662
#  n_tokens_title                                 0.040550  0.008783
#  n_tokens_content                               0.013439  0.002459
#  n_unique_tokens                               -0.004217  0.000806
#  n_non_stop_words                              -0.004391  0.000443
#  n_non_stop_unique_tokens                      -0.005342  0.000114
#  num_hrefs                                      0.056525  0.045404
#  num_self_hrefs                                -0.006709 -0.001900
#  num_imgs                                       0.063307  0.039388
#  num_videos                                     0.055231  0.023936
#
# [10 rows x 60 columns]

# %%
most = cor[abs(cor) > .75].dropna(thresh=2,axis = 0)
most
# Out:
#                               timedelta   n_tokens_title   n_tokens_content  \
#  n_unique_tokens                    NaN              NaN                NaN
#  n_non_stop_words                   NaN              NaN                NaN
#  n_non_stop_unique_tokens           NaN              NaN                NaN
#  data_channel_is_bus                NaN              NaN                NaN
#  data_channel_is_world              NaN              NaN                NaN
#  kw_min_min                         NaN              NaN                NaN
#  kw_max_min                         NaN              NaN                NaN
#  kw_avg_min                         NaN              NaN                NaN
#  kw_max_max                         NaN              NaN                NaN
#  kw_max_avg                         NaN              NaN                NaN
#  kw_avg_avg                         NaN              NaN                NaN
#  self_reference_min_shares          NaN              NaN                NaN
#  self_reference_max_shares          NaN              NaN                NaN
#  self_reference_avg_sharess         NaN              NaN                NaN
#  LDA_00                             NaN              NaN                NaN
#  LDA_02                             NaN              NaN                NaN
#  global_rate_negative_words         NaN              NaN                NaN
#  rate_negative_words                NaN              NaN                NaN
#
#                               n_unique_tokens   n_non_stop_words  \
#  n_unique_tokens                     1.000000           0.999572
#  n_non_stop_words                    0.999572           1.000000
#  n_non_stop_unique_tokens            0.999852           0.999532
#  data_channel_is_bus                      NaN                NaN
#  data_channel_is_world                    NaN                NaN
#  kw_min_min                               NaN                NaN
#  kw_max_min                               NaN                NaN
#  kw_avg_min                               NaN                NaN
#  kw_max_max                               NaN                NaN
#  kw_max_avg                               NaN                NaN
#  kw_avg_avg                               NaN                NaN
#  self_reference_min_shares                NaN                NaN
#  self_reference_max_shares                NaN                NaN
#  self_reference_avg_sharess               NaN                NaN
#  LDA_00                                   NaN                NaN
#  LDA_02                                   NaN                NaN
#  global_rate_negative_words               NaN                NaN
#  rate_negative_words                      NaN                NaN
#
#                               n_non_stop_unique_tokens   num_hrefs  \
#  n_unique_tokens                              0.999852         NaN
#  n_non_stop_words                             0.999532         NaN
#  n_non_stop_unique_tokens                     1.000000         NaN
#  data_channel_is_bus                               NaN         NaN
#  data_channel_is_world                             NaN         NaN
#  kw_min_min                                        NaN         NaN
#  kw_max_min                                        NaN         NaN
#  kw_avg_min                                        NaN         NaN
#  kw_max_max                                        NaN         NaN
#  kw_max_avg                                        NaN         NaN
#  kw_avg_avg                                        NaN         NaN
#  self_reference_min_shares                         NaN         NaN
#  self_reference_max_shares                         NaN         NaN
#  self_reference_avg_sharess                        NaN         NaN
#  LDA_00                                            NaN         NaN
#  LDA_02                                            NaN         NaN
#  global_rate_negative_words                        NaN         NaN
#  rate_negative_words                               NaN         NaN
#
#                               num_self_hrefs   num_imgs   num_videos  ...  \
#  n_unique_tokens                         NaN        NaN          NaN  ...
#  n_non_stop_words                        NaN        NaN          NaN  ...
#  n_non_stop_unique_tokens                NaN        NaN          NaN  ...
#  data_channel_is_bus                     NaN        NaN          NaN  ...
#  data_channel_is_world                   NaN        NaN          NaN  ...
#  kw_min_min                              NaN        NaN          NaN  ...
#  kw_max_min                              NaN        NaN          NaN  ...
#  kw_avg_min                              NaN        NaN          NaN  ...
#  kw_max_max                              NaN        NaN          NaN  ...
#  kw_max_avg                              NaN        NaN          NaN  ...
#  kw_avg_avg                              NaN        NaN          NaN  ...
#  self_reference_min_shares               NaN        NaN          NaN  ...
#  self_reference_max_shares               NaN        NaN          NaN  ...
#  self_reference_avg_sharess              NaN        NaN          NaN  ...
#  LDA_00                                  NaN        NaN          NaN  ...
#  LDA_02                                  NaN        NaN          NaN  ...
#  global_rate_negative_words              NaN        NaN          NaN  ...
#  rate_negative_words                     NaN        NaN          NaN  ...
#
#                               min_positive_polarity   max_positive_polarity  \
#  n_unique_tokens                                NaN                     NaN
#  n_non_stop_words                               NaN                     NaN
#  n_non_stop_unique_tokens                       NaN                     NaN
#  data_channel_is_bus                            NaN                     NaN
#  data_channel_is_world                          NaN                     NaN
#  kw_min_min                                     NaN                     NaN
#  kw_max_min                                     NaN                     NaN
#  kw_avg_min                                     NaN                     NaN
#  kw_max_max                                     NaN                     NaN
#  kw_max_avg                                     NaN                     NaN
#  kw_avg_avg                                     NaN                     NaN
#  self_reference_min_shares                      NaN                     NaN
#  self_reference_max_shares                      NaN                     NaN
#  self_reference_avg_sharess                     NaN                     NaN
#  LDA_00                                         NaN                     NaN
#  LDA_02                                         NaN                     NaN
#  global_rate_negative_words                     NaN                     NaN
#  rate_negative_words                            NaN                     NaN
#
#                               avg_negative_polarity   min_negative_polarity  \
#  n_unique_tokens                                NaN                     NaN
#  n_non_stop_words                               NaN                     NaN
#  n_non_stop_unique_tokens                       NaN                     NaN
#  data_channel_is_bus                            NaN                     NaN
#  data_channel_is_world                          NaN                     NaN
#  kw_min_min                                     NaN                     NaN
#  kw_max_min                                     NaN                     NaN
#  kw_avg_min                                     NaN                     NaN
#  kw_max_max                                     NaN                     NaN
#  kw_max_avg                                     NaN                     NaN
#  kw_avg_avg                                     NaN                     NaN
#  self_reference_min_shares                      NaN                     NaN
#  self_reference_max_shares                      NaN                     NaN
#  self_reference_avg_sharess                     NaN                     NaN
#  LDA_00                                         NaN                     NaN
#  LDA_02                                         NaN                     NaN
#  global_rate_negative_words                     NaN                     NaN
#  rate_negative_words                            NaN                     NaN
#
#                               max_negative_polarity   title_subjectivity  \
#  n_unique_tokens                                NaN                  NaN
#  n_non_stop_words                               NaN                  NaN
#  n_non_stop_unique_tokens                       NaN                  NaN
#  data_channel_is_bus                            NaN                  NaN
#  data_channel_is_world                          NaN                  NaN
#  kw_min_min                                     NaN                  NaN
#  kw_max_min                                     NaN                  NaN
#  kw_avg_min                                     NaN                  NaN
#  kw_max_max                                     NaN                  NaN
#  kw_max_avg                                     NaN                  NaN
#  kw_avg_avg                                     NaN                  NaN
#  self_reference_min_shares                      NaN                  NaN
#  self_reference_max_shares                      NaN                  NaN
#  self_reference_avg_sharess                     NaN                  NaN
#  LDA_00                                         NaN                  NaN
#  LDA_02                                         NaN                  NaN
#  global_rate_negative_words                     NaN                  NaN
#  rate_negative_words                            NaN                  NaN
#
#                               title_sentiment_polarity  \
#  n_unique_tokens                                   NaN
#  n_non_stop_words                                  NaN
#  n_non_stop_unique_tokens                          NaN
#  data_channel_is_bus                               NaN
#  data_channel_is_world                             NaN
#  kw_min_min                                        NaN
#  kw_max_min                                        NaN
#  kw_avg_min                                        NaN
#  kw_max_max                                        NaN
#  kw_max_avg                                        NaN
#  kw_avg_avg                                        NaN
#  self_reference_min_shares                         NaN
#  self_reference_max_shares                         NaN
#  self_reference_avg_sharess                        NaN
#  LDA_00                                            NaN
#  LDA_02                                            NaN
#  global_rate_negative_words                        NaN
#  rate_negative_words                               NaN
#
#                               abs_title_subjectivity  \
#  n_unique_tokens                                 NaN
#  n_non_stop_words                                NaN
#  n_non_stop_unique_tokens                        NaN
#  data_channel_is_bus                             NaN
#  data_channel_is_world                           NaN
#  kw_min_min                                      NaN
#  kw_max_min                                      NaN
#  kw_avg_min                                      NaN
#  kw_max_max                                      NaN
#  kw_max_avg                                      NaN
#  kw_avg_avg                                      NaN
#  self_reference_min_shares                       NaN
#  self_reference_max_shares                       NaN
#  self_reference_avg_sharess                      NaN
#  LDA_00                                          NaN
#  LDA_02                                          NaN
#  global_rate_negative_words                      NaN
#  rate_negative_words                             NaN
#
#                               abs_title_sentiment_polarity   shares
#  n_unique_tokens                                       NaN      NaN
#  n_non_stop_words                                      NaN      NaN
#  n_non_stop_unique_tokens                              NaN      NaN
#  data_channel_is_bus                                   NaN      NaN
#  data_channel_is_world                                 NaN      NaN
#  kw_min_min                                            NaN      NaN
#  kw_max_min                                            NaN      NaN
#  kw_avg_min                                            NaN      NaN
#  kw_max_max                                            NaN      NaN
#  kw_max_avg                                            NaN      NaN
#  kw_avg_avg                                            NaN      NaN
#  self_reference_min_shares                             NaN      NaN
#  self_reference_max_shares                             NaN      NaN
#  self_reference_avg_sharess                            NaN      NaN
#  LDA_00                                                NaN      NaN
#  LDA_02                                                NaN      NaN
#  global_rate_negative_words                            NaN      NaN
#  rate_negative_words                                   NaN      NaN
#
# [18 rows x 60 columns]

# %%
deleteColumns = most.index

# %%
newData = data.drop(columns=deleteColumns)
newData.head(10)
# Out:
#     timedelta   n_tokens_title   n_tokens_content   num_hrefs  \
# 0       731.0             12.0              219.0         4.0
# 1       731.0              9.0              255.0         3.0
# 2       731.0              9.0              211.0         3.0
# 3       731.0              9.0              531.0         9.0
# 4       731.0             13.0             1072.0        19.0
# 5       731.0             10.0              370.0         2.0
# 6       731.0              8.0              960.0        21.0
# 7       731.0             12.0              989.0        20.0
# 8       731.0             11.0               97.0         2.0
# 9       731.0             10.0              231.0         4.0
#
#     num_self_hrefs   num_imgs   num_videos   average_token_length  \
# 0              2.0        1.0          0.0               4.680365
# 1              1.0        1.0          0.0               4.913725
# 2              1.0        1.0          0.0               4.393365
# 3              0.0        1.0          0.0               4.404896
# 4             19.0       20.0          0.0               4.682836
# 5              2.0        0.0          0.0               4.359459
# 6             20.0       20.0          0.0               4.654167
# 7             20.0       20.0          0.0               4.617796
# 8              0.0        0.0          0.0               4.855670
# 9              1.0        1.0          1.0               5.090909
#
#     num_keywords   data_channel_is_lifestyle  ...   min_positive_polarity  \
# 0            5.0                         0.0  ...                0.100000
# 1            4.0                         0.0  ...                0.033333
# 2            6.0                         0.0  ...                0.100000
# 3            7.0                         0.0  ...                0.136364
# 4            7.0                         0.0  ...                0.033333
# 5            9.0                         0.0  ...                0.136364
# 6           10.0                         1.0  ...                0.100000
# 7            9.0                         0.0  ...                0.100000
# 8            7.0                         0.0  ...                0.400000
# 9            5.0                         0.0  ...                0.100000
#
#     max_positive_polarity   avg_negative_polarity   min_negative_polarity  \
# 0                     0.7               -0.350000                  -0.600
# 1                     0.7               -0.118750                  -0.125
# 2                     1.0               -0.466667                  -0.800
# 3                     0.8               -0.369697                  -0.600
# 4                     1.0               -0.220192                  -0.500
# 5                     0.6               -0.195000                  -0.400
# 6                     1.0               -0.224479                  -0.500
# 7                     1.0               -0.242778                  -0.500
# 8                     0.8               -0.125000                  -0.125
# 9                     0.5               -0.238095                  -0.500
#
#     max_negative_polarity   title_subjectivity   title_sentiment_polarity  \
# 0               -0.200000             0.500000                  -0.187500
# 1               -0.100000             0.000000                   0.000000
# 2               -0.133333             0.000000                   0.000000
# 3               -0.166667             0.000000                   0.000000
# 4               -0.050000             0.454545                   0.136364
# 5               -0.100000             0.642857                   0.214286
# 6               -0.050000             0.000000                   0.000000
# 7               -0.050000             1.000000                   0.500000
# 8               -0.125000             0.125000                   0.000000
# 9               -0.100000             0.000000                   0.000000
#
#     abs_title_subjectivity   abs_title_sentiment_polarity   shares
# 0                 0.000000                       0.187500      593
# 1                 0.500000                       0.000000      711
# 2                 0.500000                       0.000000     1500
# 3                 0.500000                       0.000000     1200
# 4                 0.045455                       0.136364      505
# 5                 0.142857                       0.214286      855
# 6                 0.500000                       0.000000      556
# 7                 0.500000                       0.500000      891
# 8                 0.375000                       0.000000     3600
# 9                 0.500000                       0.000000      710
#
# [10 rows x 42 columns]

# %%
cor=newData.corr()
plt.figure(figsize=(15,15))
df_lt = cor.where(np.tril(np.ones(cor.shape)).astype(np.bool))
sns.heatmap(df_lt,cmap='Blues')
# Out:
# /var/folders/nb/s2fx_kf54nv8fpngr1jppkjh0000gn/T/ipykernel_10633/132436370.py:3: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   df_lt = cor.where(np.tril(np.ones(cor.shape)).astype(np.bool))
# <AxesSubplot:>

# %%
cor.describe()
# Out:
#         timedelta   n_tokens_title   n_tokens_content   num_hrefs  \
# count   42.000000        42.000000          42.000000   42.000000
# mean     0.034100         0.008213           0.064774    0.081476
# std      0.191452         0.169271           0.214234    0.197154
# min     -0.493093        -0.240320          -0.450603   -0.263576
# 25%     -0.006042        -0.052527          -0.009142   -0.012255
# 50%      0.004325        -0.007468           0.024383    0.047937
# 75%      0.073348         0.010899           0.102514    0.111304
# max      1.000000         1.000000           1.000000    1.000000
#
#         num_self_hrefs   num_imgs   num_videos   average_token_length  \
# count        42.000000  42.000000    42.000000              42.000000
# mean          0.076387   0.064913     0.043636               0.075931
# std           0.177856   0.176596     0.169946               0.249988
# min          -0.122071  -0.136522    -0.138190              -0.324529
# 25%          -0.013652  -0.008550    -0.015685              -0.033217
# 50%           0.032688   0.025026     0.008097               0.002589
# 75%           0.111358   0.076177     0.069474               0.129568
# max           1.000000   1.000000     1.000000               1.000000
#
#         num_keywords   data_channel_is_lifestyle  ...   min_positive_polarity  \
# count      42.000000                   42.000000  ...               42.000000
# mean        0.030468                    0.030222  ...                0.036202
# std         0.183703                    0.166917  ...                0.187046
# min        -0.332221                   -0.132091  ...               -0.261493
# 25%        -0.015470                   -0.022059  ...               -0.015079
# 50%         0.023130                    0.006346  ...                0.002526
# 75%         0.061534                    0.047530  ...                0.023987
# max         1.000000                    1.000000  ...                1.000000
#
#         max_positive_polarity   avg_negative_polarity   min_negative_polarity  \
# count               42.000000               42.000000               42.000000
# mean                 0.122271                0.004548               -0.005477
# std                  0.250089                0.250588                0.244386
# min                 -0.360871               -0.443187               -0.450603
# 25%                 -0.009659               -0.096128               -0.094370
# 50%                  0.039379               -0.019732               -0.014914
# 75%                  0.147839                0.007780                0.014018
# max                  1.000000                1.000000                1.000000
#
#         max_negative_polarity   title_subjectivity   title_sentiment_polarity  \
# count               42.000000            42.000000                  42.000000
# mean                 0.019147             0.050758                   0.063944
# std                  0.196936             0.208690                   0.174384
# min                 -0.223191            -0.487172                  -0.240112
# 25%                 -0.022054            -0.011136                  -0.000293
# 50%                 -0.002713             0.018990                   0.025068
# 75%                  0.020879             0.052683                   0.044493
# max                  1.000000             1.000000                   1.000000
#
#         abs_title_subjectivity   abs_title_sentiment_polarity     shares
# count                42.000000                      42.000000  42.000000
# mean                 -0.015323                       0.060611   0.031327
# std                   0.191363                       0.208327   0.154685
# min                  -0.487172                      -0.400272  -0.032029
# 25%                  -0.021473                      -0.004177  -0.006927
# 50%                  -0.008552                       0.022358   0.005426
# 75%                   0.008738                       0.056202   0.020603
# max                   1.000000                       1.000000   1.000000
#
# [8 rows x 42 columns]

# %% [markdown]
# # most correlation with shares

# %%
mostSharesCorrelation = cor[abs(cor[' shares']) >= .02]
mostSharesCorrelation
# Out:
#                                 timedelta   n_tokens_title   n_tokens_content  \
#  num_hrefs                      -0.000832        -0.053496           0.423065
#  num_imgs                       -0.027636        -0.008858           0.342600
#  num_videos                      0.000936         0.051460           0.103699
#  average_token_length            0.130465        -0.071403           0.167789
#  num_keywords                    0.046884        -0.006077           0.072845
#  kw_avg_max                     -0.493093         0.115746          -0.096460
#  kw_min_avg                     -0.157204        -0.002370          -0.022286
#  LDA_03                         -0.030838         0.042208          -0.140141
#  global_subjectivity             0.133837        -0.056804           0.127879
#  avg_negative_polarity          -0.000507        -0.017096          -0.130375
#  title_subjectivity             -0.015919         0.077245           0.004484
#  abs_title_sentiment_polarity   -0.002745         0.040550           0.013439
#  shares                          0.008662         0.008783           0.002459
#
#                                 num_hrefs   num_self_hrefs   num_imgs  \
#  num_hrefs                       1.000000         0.396452   0.342633
#  num_imgs                        0.342633         0.238586   1.000000
#  num_videos                      0.114518         0.077458  -0.067336
#  average_token_length            0.222588         0.126879   0.033924
#  num_keywords                    0.125890         0.099578   0.088432
#  kw_avg_max                     -0.019269        -0.064747   0.002217
#  kw_min_avg                      0.058920         0.039239   0.081029
#  LDA_03                          0.123786        -0.028775   0.208924
#  global_subjectivity             0.203464         0.115285   0.080468
#  avg_negative_polarity          -0.152146        -0.058222  -0.072500
#  title_subjectivity              0.043950        -0.011239   0.056815
#  abs_title_sentiment_polarity    0.056525        -0.006709   0.063307
#  shares                          0.045404        -0.001900   0.039388
#
#                                 num_videos   average_token_length  \
#  num_hrefs                        0.114518               0.222588
#  num_imgs                        -0.067336               0.033924
#  num_videos                       1.000000              -0.002940
#  average_token_length            -0.002940               1.000000
#  num_keywords                    -0.022257              -0.016814
#  kw_avg_max                       0.136228              -0.157419
#  kw_min_avg                       0.058866              -0.076706
#  LDA_03                           0.267673              -0.181714
#  global_subjectivity              0.082052               0.597629
#  avg_negative_polarity           -0.115976              -0.324529
#  title_subjectivity               0.061028              -0.040406
#  abs_title_sentiment_polarity     0.055231              -0.036953
#  shares                           0.023936              -0.022007
#
#                                 num_keywords   data_channel_is_lifestyle  ...  \
#  num_hrefs                          0.125890                    0.052906  ...
#  num_imgs                           0.088432                    0.010260  ...
#  num_videos                        -0.022257                   -0.044602  ...
#  average_token_length              -0.016814                    0.011161  ...
#  num_keywords                       1.000000                    0.124578  ...
#  kw_avg_max                        -0.332221                   -0.132091  ...
#  kw_min_avg                        -0.272042                   -0.010045  ...
#  LDA_03                             0.022726                   -0.063131  ...
#  global_subjectivity                0.038603                    0.060423  ...
#  avg_negative_polarity              0.021114                   -0.006529  ...
#  title_subjectivity                 0.016014                    0.002736  ...
#  abs_title_sentiment_polarity       0.023533                    0.017966  ...
#  shares                             0.021818                    0.005831  ...
#
#                                 min_positive_polarity   max_positive_polarity  \
#  num_hrefs                                  -0.082168                0.286733
#  num_imgs                                   -0.024683                0.155232
#  num_videos                                 -0.010103                0.125659
#  average_token_length                        0.222207                0.471383
#  num_keywords                               -0.015890                0.062440
#  kw_avg_max                                  0.006972               -0.097967
#  kw_min_avg                                  0.015884               -0.012181
#  LDA_03                                      0.108755               -0.014059
#  global_subjectivity                         0.243984                0.518773
#  avg_negative_polarity                      -0.063571               -0.268784
#  title_subjectivity                          0.008327                0.052790
#  abs_title_sentiment_polarity                0.011512                0.082966
#  shares                                     -0.000040                0.010068
#
#                                 avg_negative_polarity   min_negative_polarity  \
#  num_hrefs                                  -0.152146               -0.263576
#  num_imgs                                   -0.072500               -0.136522
#  num_videos                                 -0.115976               -0.138190
#  average_token_length                       -0.324529               -0.278784
#  num_keywords                                0.021114               -0.002656
#  kw_avg_max                                 -0.021485                0.014258
#  kw_min_avg                                 -0.020031               -0.004458
#  LDA_03                                     -0.114381               -0.025578
#  global_subjectivity                        -0.443187               -0.350070
#  avg_negative_polarity                       1.000000                0.748896
#  title_subjectivity                         -0.075814               -0.057639
#  abs_title_sentiment_polarity               -0.075594               -0.058398
#  shares                                     -0.032029               -0.019297
#
#                                 max_negative_polarity   title_subjectivity  \
#  num_hrefs                                   0.054948             0.043950
#  num_imgs                                    0.042644             0.056815
#  num_videos                                  0.027251             0.061028
#  average_token_length                       -0.194660            -0.040406
#  num_keywords                                0.028036             0.016014
#  kw_avg_max                                 -0.022972             0.047235
#  kw_min_avg                                 -0.009388             0.045342
#  LDA_03                                     -0.074780             0.129062
#  global_subjectivity                        -0.223191             0.114123
#  avg_negative_polarity                       0.580108            -0.075814
#  title_subjectivity                         -0.015788             1.000000
#  abs_title_sentiment_polarity               -0.017444             0.714528
#  shares                                     -0.019300             0.021967
#
#                                 title_sentiment_polarity  \
#  num_hrefs                                      0.039041
#  num_imgs                                       0.046310
#  num_videos                                     0.021980
#  average_token_length                          -0.016718
#  num_keywords                                   0.031705
#  kw_avg_max                                    -0.010713
#  kw_min_avg                                     0.024973
#  LDA_03                                         0.027687
#  global_subjectivity                            0.034075
#  avg_negative_polarity                          0.085878
#  title_subjectivity                             0.232130
#  abs_title_sentiment_polarity                   0.410205
#  shares                                         0.012772
#
#                                 abs_title_subjectivity  \
#  num_hrefs                                    0.009443
#  num_imgs                                    -0.013759
#  num_videos                                  -0.021982
#  average_token_length                         0.026586
#  num_keywords                                -0.010992
#  kw_avg_max                                  -0.015096
#  kw_min_avg                                  -0.016834
#  LDA_03                                      -0.013784
#  global_subjectivity                         -0.003758
#  avg_negative_polarity                       -0.006573
#  title_subjectivity                          -0.487172
#  abs_title_sentiment_polarity                -0.400272
#  shares                                       0.001481
#
#                                 abs_title_sentiment_polarity    shares
#  num_hrefs                                          0.056525  0.045404
#  num_imgs                                           0.063307  0.039388
#  num_videos                                         0.055231  0.023936
#  average_token_length                              -0.036953 -0.022007
#  num_keywords                                       0.023533  0.021818
#  kw_avg_max                                         0.035188  0.044686
#  kw_min_avg                                         0.054769  0.039551
#  LDA_03                                             0.122120  0.083771
#  global_subjectivity                                0.091067  0.031604
#  avg_negative_polarity                             -0.075594 -0.032029
#  title_subjectivity                                 0.714528  0.021967
#  abs_title_sentiment_polarity                       1.000000  0.027135
#  shares                                             0.027135  1.000000
#
# [13 rows x 42 columns]

# %%
x = np.arange(len(mostSharesCorrelation[' shares']))
width = .25
fig, ax = plt.subplots()
ax.bar(x,mostSharesCorrelation[' shares'],width)
labels = mostSharesCorrelation[' shares'].index
ax.set_ylabel('correlation')
ax.set_title("most correlation with shares")
ax.set_xticks(x)
ax.legend()
plt.figure(figsize=(20,30))
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # Set New Data

# %%
data = newData
originData = newData
data.head()
# Out:
#     timedelta   n_tokens_title   n_tokens_content   num_hrefs  \
# 0       731.0             12.0              219.0         4.0
# 1       731.0              9.0              255.0         3.0
# 2       731.0              9.0              211.0         3.0
# 3       731.0              9.0              531.0         9.0
# 4       731.0             13.0             1072.0        19.0
#
#     num_self_hrefs   num_imgs   num_videos   average_token_length  \
# 0              2.0        1.0          0.0               4.680365
# 1              1.0        1.0          0.0               4.913725
# 2              1.0        1.0          0.0               4.393365
# 3              0.0        1.0          0.0               4.404896
# 4             19.0       20.0          0.0               4.682836
#
#     num_keywords   data_channel_is_lifestyle  ...   min_positive_polarity  \
# 0            5.0                         0.0  ...                0.100000
# 1            4.0                         0.0  ...                0.033333
# 2            6.0                         0.0  ...                0.100000
# 3            7.0                         0.0  ...                0.136364
# 4            7.0                         0.0  ...                0.033333
#
#     max_positive_polarity   avg_negative_polarity   min_negative_polarity  \
# 0                     0.7               -0.350000                  -0.600
# 1                     0.7               -0.118750                  -0.125
# 2                     1.0               -0.466667                  -0.800
# 3                     0.8               -0.369697                  -0.600
# 4                     1.0               -0.220192                  -0.500
#
#     max_negative_polarity   title_subjectivity   title_sentiment_polarity  \
# 0               -0.200000             0.500000                  -0.187500
# 1               -0.100000             0.000000                   0.000000
# 2               -0.133333             0.000000                   0.000000
# 3               -0.166667             0.000000                   0.000000
# 4               -0.050000             0.454545                   0.136364
#
#     abs_title_subjectivity   abs_title_sentiment_polarity   shares
# 0                 0.000000                       0.187500      593
# 1                 0.500000                       0.000000      711
# 2                 0.500000                       0.000000     1500
# 3                 0.500000                       0.000000     1200
# 4                 0.045455                       0.136364      505
#
# [5 rows x 42 columns]

# %% [markdown]
# # find outlier records

# %% [markdown]
# ### IQR

# %%
for column in data.columns:    
    q1 = data[column].quantile(0.25)    # First Quartile
    q3 = data[column].quantile(0.75)    # Third Quartile
    IQR = q3 - q1                            # Inter Quartile Range

    llimit = q1 - 1.5*IQR                       # Lower Limit
    ulimit = q3 + 1.5*IQR                        # Upper Limit

    df = data[(data[column] > llimit) & (data[column] < ulimit)]
    
df
# Out:
#         timedelta   n_tokens_title   n_tokens_content   num_hrefs  \
# 0           731.0             12.0              219.0         4.0
# 1           731.0              9.0              255.0         3.0
# 2           731.0              9.0              211.0         3.0
# 3           731.0              9.0              531.0         9.0
# 4           731.0             13.0             1072.0        19.0
# ...           ...              ...                ...         ...
# 39639         8.0             11.0              346.0         9.0
# 39640         8.0             12.0              328.0         9.0
# 39641         8.0             10.0              442.0        24.0
# 39642         8.0              6.0              682.0        10.0
# 39643         8.0             10.0              157.0         1.0
#
#         num_self_hrefs   num_imgs   num_videos   average_token_length  \
# 0                  2.0        1.0          0.0               4.680365
# 1                  1.0        1.0          0.0               4.913725
# 2                  1.0        1.0          0.0               4.393365
# 3                  0.0        1.0          0.0               4.404896
# 4                 19.0       20.0          0.0               4.682836
# ...                ...        ...          ...                    ...
# 39639              7.0        1.0          1.0               4.523121
# 39640              7.0        3.0         48.0               4.405488
# 39641              1.0       12.0          1.0               5.076923
# 39642              1.0        1.0          0.0               4.975073
# 39643              1.0        0.0          2.0               4.471338
#
#         num_keywords   data_channel_is_lifestyle  ...   min_positive_polarity  \
# 0                5.0                         0.0  ...                0.100000
# 1                4.0                         0.0  ...                0.033333
# 2                6.0                         0.0  ...                0.100000
# 3                7.0                         0.0  ...                0.136364
# 4                7.0                         0.0  ...                0.033333
# ...              ...                         ...  ...                     ...
# 39639            8.0                         0.0  ...                0.100000
# 39640            7.0                         0.0  ...                0.136364
# 39641            8.0                         0.0  ...                0.136364
# 39642            5.0                         0.0  ...                0.062500
# 39643            4.0                         0.0  ...                0.100000
#
#         max_positive_polarity   avg_negative_polarity   min_negative_polarity  \
# 0                        0.70               -0.350000                  -0.600
# 1                        0.70               -0.118750                  -0.125
# 2                        1.00               -0.466667                  -0.800
# 3                        0.80               -0.369697                  -0.600
# 4                        1.00               -0.220192                  -0.500
# ...                       ...                     ...                     ...
# 39639                    0.75               -0.260000                  -0.500
# 39640                    0.70               -0.211111                  -0.400
# 39641                    0.50               -0.356439                  -0.800
# 39642                    0.50               -0.205246                  -0.500
# 39643                    0.50               -0.200000                  -0.200
#
#         max_negative_polarity   title_subjectivity   title_sentiment_polarity  \
# 0                   -0.200000             0.500000                  -0.187500
# 1                   -0.100000             0.000000                   0.000000
# 2                   -0.133333             0.000000                   0.000000
# 3                   -0.166667             0.000000                   0.000000
# 4                   -0.050000             0.454545                   0.136364
# ...                       ...                  ...                        ...
# 39639               -0.125000             0.100000                   0.000000
# 39640               -0.100000             0.300000                   1.000000
# 39641               -0.166667             0.454545                   0.136364
# 39642               -0.012500             0.000000                   0.000000
# 39643               -0.200000             0.333333                   0.250000
#
#         abs_title_subjectivity   abs_title_sentiment_polarity   shares
# 0                     0.000000                       0.187500      593
# 1                     0.500000                       0.000000      711
# 2                     0.500000                       0.000000     1500
# 3                     0.500000                       0.000000     1200
# 4                     0.045455                       0.136364      505
# ...                        ...                            ...      ...
# 39639                 0.400000                       0.000000     1800
# 39640                 0.200000                       1.000000     1900
# 39641                 0.045455                       0.136364     1900
# 39642                 0.500000                       0.000000     1100
# 39643                 0.166667                       0.250000     1300
#
# [35103 rows x 42 columns]

# %% [markdown]
# ### z-test

# %%
sns.distplot(data[' shares'], bins=20)
# Out:
# /Users/rezamosavi/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel=' shares', ylabel='Density'>

# %%
def edit(x):
    return np.log(x) + 1

temp = data.apply(edit)
temp
# Out:
# /Users/rezamosavi/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/rezamosavi/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#         timedelta   n_tokens_title   n_tokens_content   num_hrefs  \
# 0        7.594413         3.484907           6.389072    2.386294
# 1        7.594413         3.197225           6.541264    2.098612
# 2        7.594413         3.197225           6.351858    2.098612
# 3        7.594413         3.197225           7.274762    3.197225
# 4        7.594413         3.564949           7.977281    3.944439
# ...           ...              ...                ...         ...
# 39639    3.079442         3.397895           6.846439    3.197225
# 39640    3.079442         3.484907           6.793014    3.197225
# 39641    3.079442         3.302585           7.091310    4.178054
# 39642    3.079442         2.791759           7.525030    3.302585
# 39643    3.079442         3.302585           6.056246    1.000000
#
#         num_self_hrefs   num_imgs   num_videos   average_token_length  \
# 0             1.693147   1.000000         -inf               2.543376
# 1             1.000000   1.000000         -inf               2.592032
# 2             1.000000   1.000000         -inf               2.480095
# 3                 -inf   1.000000         -inf               2.482717
# 4             3.944439   3.995732         -inf               2.543904
# ...                ...        ...          ...                    ...
# 39639         2.945910   1.000000     1.000000               2.509202
# 39640         2.945910   2.098612     4.871201               2.482851
# 39641         1.000000   3.484907     1.000000               2.624705
# 39642         1.000000   1.000000         -inf               2.604440
# 39643         1.000000       -inf     1.693147               2.497688
#
#         num_keywords   data_channel_is_lifestyle  ...   min_positive_polarity  \
# 0           2.609438                        -inf  ...               -1.302585
# 1           2.386294                        -inf  ...               -2.401197
# 2           2.791759                        -inf  ...               -1.302585
# 3           2.945910                        -inf  ...               -0.992430
# 4           2.945910                        -inf  ...               -2.401197
# ...              ...                         ...  ...                     ...
# 39639       3.079442                        -inf  ...               -1.302585
# 39640       2.945910                        -inf  ...               -0.992430
# 39641       3.079442                        -inf  ...               -0.992430
# 39642       2.609438                        -inf  ...               -1.772589
# 39643       2.386294                        -inf  ...               -1.302585
#
#         max_positive_polarity   avg_negative_polarity   min_negative_polarity  \
# 0                    0.643325                     NaN                     NaN
# 1                    0.643325                     NaN                     NaN
# 2                    1.000000                     NaN                     NaN
# 3                    0.776856                     NaN                     NaN
# 4                    1.000000                     NaN                     NaN
# ...                       ...                     ...                     ...
# 39639                0.712318                     NaN                     NaN
# 39640                0.643325                     NaN                     NaN
# 39641                0.306853                     NaN                     NaN
# 39642                0.306853                     NaN                     NaN
# 39643                0.306853                     NaN                     NaN
#
#         max_negative_polarity   title_subjectivity   title_sentiment_polarity  \
# 0                         NaN             0.306853                        NaN
# 1                         NaN                 -inf                       -inf
# 2                         NaN                 -inf                       -inf
# 3                         NaN                 -inf                       -inf
# 4                         NaN             0.211543                  -0.992430
# ...                       ...                  ...                        ...
# 39639                     NaN            -1.302585                       -inf
# 39640                     NaN            -0.203973                   1.000000
# 39641                     NaN             0.211543                  -0.992430
# 39642                     NaN                 -inf                       -inf
# 39643                     NaN            -0.098612                  -0.386294
#
#         abs_title_subjectivity   abs_title_sentiment_polarity    shares
# 0                         -inf                      -0.673976  7.385194
# 1                     0.306853                           -inf  7.566672
# 2                     0.306853                           -inf  8.313220
# 3                     0.306853                           -inf  8.090077
# 4                    -2.091042                      -0.992430  7.224558
# ...                        ...                            ...       ...
# 39639                 0.083709                           -inf  8.495542
# 39640                -0.609438                       1.000000  8.549609
# 39641                -2.091042                      -0.992430  8.549609
# 39642                 0.306853                           -inf  8.003065
# 39643                -0.791759                      -0.386294  8.170120
#
# [39644 rows x 42 columns]

# %%
sns.distplot(temp[' shares'], bins=20)
# Out:
# /Users/rezamosavi/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel=' shares', ylabel='Density'>

# %%
for column in temp.columns:    
    temp[column] = (temp[column] - temp[column].mean())/temp[column].var()
    outliers = temp[(temp[column] < 3) | (temp[column] > -3)]
    
outliers
# Out:
#         timedelta   n_tokens_title   n_tokens_content   num_hrefs  \
# 0        1.014322         0.164768                NaN         NaN
# 1        1.014322        -0.122914                NaN         NaN
# 2        1.014322        -0.122914                NaN         NaN
# 3        1.014322        -0.122914                NaN         NaN
# 4        1.014322         0.244810                NaN         NaN
# ...           ...              ...                ...         ...
# 39639   -3.500650         0.077756                NaN         NaN
# 39640   -3.500650         0.164768                NaN         NaN
# 39641   -3.500650        -0.017554                NaN         NaN
# 39642   -3.500650        -0.528379                NaN         NaN
# 39643   -3.500650        -0.017554                NaN         NaN
#
#         num_self_hrefs   num_imgs   num_videos   average_token_length  \
# 0                  NaN        NaN          NaN                    NaN
# 1                  NaN        NaN          NaN                    NaN
# 2                  NaN        NaN          NaN                    NaN
# 3                  NaN        NaN          NaN                    NaN
# 4                  NaN        NaN          NaN                    NaN
# ...                ...        ...          ...                    ...
# 39639              NaN        NaN          NaN                    NaN
# 39640              NaN        NaN          NaN                    NaN
# 39641              NaN        NaN          NaN                    NaN
# 39642              NaN        NaN          NaN                    NaN
# 39643              NaN        NaN          NaN                    NaN
#
#         num_keywords   data_channel_is_lifestyle  ...   min_positive_polarity  \
# 0          -0.328161                         NaN  ...                     NaN
# 1          -0.551304                         NaN  ...                     NaN
# 2          -0.145839                         NaN  ...                     NaN
# 3           0.008312                         NaN  ...                     NaN
# 4           0.008312                         NaN  ...                     NaN
# ...              ...                         ...  ...                     ...
# 39639       0.141843                         NaN  ...                     NaN
# 39640       0.008312                         NaN  ...                     NaN
# 39641       0.141843                         NaN  ...                     NaN
# 39642      -0.328161                         NaN  ...                     NaN
# 39643      -0.551304                         NaN  ...                     NaN
#
#         max_positive_polarity   avg_negative_polarity   min_negative_polarity  \
# 0                         NaN                     NaN                     NaN
# 1                         NaN                     NaN                     NaN
# 2                         NaN                     NaN                     NaN
# 3                         NaN                     NaN                     NaN
# 4                         NaN                     NaN                     NaN
# ...                       ...                     ...                     ...
# 39639                     NaN                     NaN                     NaN
# 39640                     NaN                     NaN                     NaN
# 39641                     NaN                     NaN                     NaN
# 39642                     NaN                     NaN                     NaN
# 39643                     NaN                     NaN                     NaN
#
#         max_negative_polarity   title_subjectivity   title_sentiment_polarity  \
# 0                         NaN                  NaN                        NaN
# 1                         NaN                  NaN                        NaN
# 2                         NaN                  NaN                        NaN
# 3                         NaN                  NaN                        NaN
# 4                         NaN                  NaN                        NaN
# ...                       ...                  ...                        ...
# 39639                     NaN                  NaN                        NaN
# 39640                     NaN                  NaN                        NaN
# 39641                     NaN                  NaN                        NaN
# 39642                     NaN                  NaN                        NaN
# 39643                     NaN                  NaN                        NaN
#
#         abs_title_subjectivity   abs_title_sentiment_polarity    shares
# 0                          NaN                            NaN -1.089661
# 1                          NaN                            NaN -0.908182
# 2                          NaN                            NaN -0.161635
# 3                          NaN                            NaN -0.384778
# 4                          NaN                            NaN -1.250296
# ...                        ...                            ...       ...
# 39639                      NaN                            NaN  0.020687
# 39640                      NaN                            NaN  0.074754
# 39641                      NaN                            NaN  0.074754
# 39642                      NaN                            NaN -0.471789
# 39643                      NaN                            NaN -0.304735
#
# [39644 rows x 42 columns]

# %%
outliers.shape

# %% [markdown]
# ### Percentile

# %%
for column in data.columns:    
    
    lower_limit, upper_limit = np.percentile(a=data[column],q=[1,99])

    tempData = data[(data[column] > lower_limit) & (data[column] < upper_limit)]
    
tempData
# Out:
#         timedelta   n_tokens_title   n_tokens_content   num_hrefs  \
# 1        5.199338        -0.628724          -0.905189   -1.111702
# 2        5.199338        -0.628724           0.291367    0.211070
# 3        5.199338        -0.157469          -0.142244   -1.435477
# 4        5.199338         0.749670           1.116369    1.125776
# 5        5.199338         0.301855          -1.727466   -1.435477
# ...           ...              ...                ...         ...
# 31634   -5.199338         0.301855          -0.227777    0.211070
# 31635   -5.199338         0.749670          -0.299230    0.211070
# 31636   -5.199338        -0.157469           0.071571    1.349498
# 31637   -5.199338        -2.144011           0.602943    0.334851
# 31638   -5.199338        -0.157469          -1.275302   -1.727466
#
#         num_self_hrefs   num_imgs   num_videos   average_token_length  \
# 1            -0.795322  -0.254902    -5.199338              -0.988303
# 2            -5.199338  -0.254902    -5.199338              -0.951833
# 3            -0.270485  -5.199338    -5.199338              -1.107015
# 4             2.307607   1.654145    -5.199338              -0.165559
# 5            -5.199338  -5.199338    -5.199338               0.675902
# ...                ...        ...          ...                    ...
# 31634         1.365257  -0.254902     0.697507              -0.509182
# 31635         1.365257   0.604448     3.197551              -0.949421
# 31636        -0.795322   1.186981     0.697507               1.419703
# 31637        -0.795322  -0.254902    -5.199338               1.080544
# 31638        -0.795322  -5.199338     1.289578              -0.702315
#
#         num_keywords   data_channel_is_lifestyle  ...   min_positive_polarity  \
# 1          -0.556927                   -5.199338  ...                0.258792
# 2          -0.084155                   -5.199338  ...                1.023003
# 3           0.743040                   -5.199338  ...                1.023003
# 4           0.743040                   -5.199338  ...                0.258792
# 5          -0.084155                   -5.199338  ...                2.345158
# ...              ...                         ...  ...                     ...
# 31634       0.346817                   -5.199338  ...                0.258792
# 31635      -0.084155                   -5.199338  ...                1.023003
# 31636       0.346817                   -5.199338  ...                1.023003
# 31637      -1.070745                   -5.199338  ...               -0.334851
# 31638      -1.649237                   -5.199338  ...                0.258792
#
#         max_positive_polarity   avg_negative_polarity   min_negative_polarity  \
# 1                    5.199338               -1.659093               -0.879040
# 2                    0.031369               -1.005981               -0.318969
# 3                   -0.562796                0.576794                0.384375
# 4                    5.199338                0.093281                0.022584
# 5                    0.031369                1.247505                1.358913
# ...                       ...                     ...                     ...
# 31634               -0.170185               -0.078140                0.022584
# 31635               -0.299230                0.400635                0.384375
# 31636               -1.048748               -0.912723               -0.879040
# 31637               -1.048748                0.462260                0.022584
# 31638               -1.048748                0.520661                0.983573
#
#         max_negative_polarity   title_subjectivity   title_sentiment_polarity  \
# 1                   -0.848075            -5.199338                  -0.263985
# 2                   -1.130517            -5.199338                  -0.263985
# 3                   -0.124523             1.010382                   0.824933
# 4                    0.764710             5.199338                   1.490335
# 5                   -0.611996             0.001255                  -0.263985
# ...                       ...                  ...                        ...
# 31634               -0.611996            -0.030114                  -0.263985
# 31635               -0.124523             0.190587                   5.199338
# 31636               -1.130517             0.524976                   0.621099
# 31637                1.471555            -5.199338                  -0.263985
# 31638               -1.431971             0.251016                   0.905189
#
#         abs_title_subjectivity   abs_title_sentiment_polarity    shares
# 1                     5.199338                      -5.199338  0.075345
# 2                     5.199338                      -5.199338 -0.326900
# 3                    -0.738089                       0.607463 -1.215372
# 4                     5.199338                       1.327982 -1.075207
# 5                    -0.207223                      -5.199338  1.236652
# ...                        ...                            ...       ...
# 31634                -0.153660                      -5.199338  0.340163
# 31635                -0.527858                       5.199338  0.411534
# 31636                -1.261282                       0.346817  0.411534
# 31637                 5.199338                      -5.199338 -0.514923
# 31638                -0.642543                       0.691121 -0.172731
#
# [30988 rows x 42 columns]

# %%
tempData.describe()
# Out:
#           timedelta   n_tokens_title   n_tokens_content     num_hrefs  \
# count  30988.000000     30988.000000       30988.000000  30988.000000
# mean       0.003091         0.002187          -0.079340     -0.089573
# std        1.014516         0.981482           1.258207      1.283658
# min       -5.199338        -5.199338          -5.199338     -5.199338
# 25%       -0.676854        -0.628724          -0.675277     -0.795322
# 50%        0.000000        -0.157469          -0.001255     -0.090452
# 75%        0.676854         0.749670           0.674752      0.636387
# max        5.199338         5.199338           5.199338      5.199338
#
#         num_self_hrefs      num_imgs    num_videos   average_token_length  \
# count     30988.000000  30988.000000  30988.000000           30988.000000
# mean         -0.457355     -0.612402     -2.959024              -0.078364
# std           1.971384      2.163288      3.004633               1.259080
# min          -5.199338     -5.199338     -5.199338              -5.199338
# 25%          -0.795322     -0.254902     -5.199338              -0.673454
# 50%           0.184203     -0.254902     -5.199338               0.002180
# 75%           0.570161      0.681594      0.697507               0.675091
# max           5.199338      5.199338      5.199338               5.199338
#
#         num_keywords   data_channel_is_lifestyle  ...   min_positive_polarity  \
# count   30988.000000                30988.000000  ...            30988.000000
# mean        0.630245                   -4.649001  ...               -0.078228
# std         2.180978                    2.328105  ...                1.234687
# min        -5.199338                   -5.199338  ...               -5.199338
# 25%        -0.556927                   -5.199338  ...               -0.595437
# 50%        -0.084155                   -5.199338  ...                0.258792
# 75%         0.743040                   -5.199338  ...                0.258792
# max         5.199338                    5.199338  ...                5.199338
#
#         max_positive_polarity   avg_negative_polarity   min_negative_polarity  \
# count            30988.000000            30988.000000            30988.000000
# mean                 1.470256                0.199027               -0.290224
# std                  2.991376                1.552790                2.378674
# min                 -5.199338               -5.199338               -5.199338
# 25%                 -0.562796               -0.672066               -0.590949
# 50%                  0.031369               -0.000199                0.022584
# 75%                  5.199338                0.674868                0.673702
# max                  5.199338                5.199338                5.199338
#
#         max_negative_polarity   title_subjectivity   title_sentiment_polarity  \
# count            30988.000000         30988.000000               30988.000000
# mean                 0.194028            -1.790568                   0.034834
# std                  1.540693             3.335696                   1.118897
# min                 -5.199338            -5.199338                  -5.199338
# 25%                 -0.611996            -5.199338                  -0.263985
# 50%                 -0.124523             0.001255                  -0.263985
# 75%                  0.764710             0.697507                   0.621099
# max                  5.199338             5.199338                   5.199338
#
#         abs_title_subjectivity   abs_title_sentiment_polarity        shares
# count             30988.000000                   30988.000000  30988.000000
# mean                  2.094365                      -2.194919     -0.000611
# std                   3.425550                       3.125215      0.932666
# min                  -5.199338                      -5.199338     -2.307607
# 25%                  -0.642543                      -5.199338     -0.680013
# 50%                   5.199338                      -5.199338     -0.040157
# 75%                   5.199338                       0.691121      0.662724
# max                   5.199338                       5.199338      2.256745
#
# [8 rows x 42 columns]

# %% [markdown]
# # Set New Data

# %%
#data = tempData
#Columns = data.columns
#data
data = df
Columns = df.columns
data
# Out:
#         timedelta   n_tokens_title   n_tokens_content   num_hrefs  \
# 0           731.0             12.0              219.0         4.0
# 1           731.0              9.0              255.0         3.0
# 2           731.0              9.0              211.0         3.0
# 3           731.0              9.0              531.0         9.0
# 4           731.0             13.0             1072.0        19.0
# ...           ...              ...                ...         ...
# 39639         8.0             11.0              346.0         9.0
# 39640         8.0             12.0              328.0         9.0
# 39641         8.0             10.0              442.0        24.0
# 39642         8.0              6.0              682.0        10.0
# 39643         8.0             10.0              157.0         1.0
#
#         num_self_hrefs   num_imgs   num_videos   average_token_length  \
# 0                  2.0        1.0          0.0               4.680365
# 1                  1.0        1.0          0.0               4.913725
# 2                  1.0        1.0          0.0               4.393365
# 3                  0.0        1.0          0.0               4.404896
# 4                 19.0       20.0          0.0               4.682836
# ...                ...        ...          ...                    ...
# 39639              7.0        1.0          1.0               4.523121
# 39640              7.0        3.0         48.0               4.405488
# 39641              1.0       12.0          1.0               5.076923
# 39642              1.0        1.0          0.0               4.975073
# 39643              1.0        0.0          2.0               4.471338
#
#         num_keywords   data_channel_is_lifestyle  ...   min_positive_polarity  \
# 0                5.0                         0.0  ...                0.100000
# 1                4.0                         0.0  ...                0.033333
# 2                6.0                         0.0  ...                0.100000
# 3                7.0                         0.0  ...                0.136364
# 4                7.0                         0.0  ...                0.033333
# ...              ...                         ...  ...                     ...
# 39639            8.0                         0.0  ...                0.100000
# 39640            7.0                         0.0  ...                0.136364
# 39641            8.0                         0.0  ...                0.136364
# 39642            5.0                         0.0  ...                0.062500
# 39643            4.0                         0.0  ...                0.100000
#
#         max_positive_polarity   avg_negative_polarity   min_negative_polarity  \
# 0                        0.70               -0.350000                  -0.600
# 1                        0.70               -0.118750                  -0.125
# 2                        1.00               -0.466667                  -0.800
# 3                        0.80               -0.369697                  -0.600
# 4                        1.00               -0.220192                  -0.500
# ...                       ...                     ...                     ...
# 39639                    0.75               -0.260000                  -0.500
# 39640                    0.70               -0.211111                  -0.400
# 39641                    0.50               -0.356439                  -0.800
# 39642                    0.50               -0.205246                  -0.500
# 39643                    0.50               -0.200000                  -0.200
#
#         max_negative_polarity   title_subjectivity   title_sentiment_polarity  \
# 0                   -0.200000             0.500000                  -0.187500
# 1                   -0.100000             0.000000                   0.000000
# 2                   -0.133333             0.000000                   0.000000
# 3                   -0.166667             0.000000                   0.000000
# 4                   -0.050000             0.454545                   0.136364
# ...                       ...                  ...                        ...
# 39639               -0.125000             0.100000                   0.000000
# 39640               -0.100000             0.300000                   1.000000
# 39641               -0.166667             0.454545                   0.136364
# 39642               -0.012500             0.000000                   0.000000
# 39643               -0.200000             0.333333                   0.250000
#
#         abs_title_subjectivity   abs_title_sentiment_polarity   shares
# 0                     0.000000                       0.187500      593
# 1                     0.500000                       0.000000      711
# 2                     0.500000                       0.000000     1500
# 3                     0.500000                       0.000000     1200
# 4                     0.045455                       0.136364      505
# ...                        ...                            ...      ...
# 39639                 0.400000                       0.000000     1800
# 39640                 0.200000                       1.000000     1900
# 39641                 0.045455                       0.136364     1900
# 39642                 0.500000                       0.000000     1100
# 39643                 0.166667                       0.250000     1300
#
# [35103 rows x 42 columns]

# %% [markdown]
# # Scaling

# %% [markdown]
# ### Quantile Transformer

# %%
quantile = QuantileTransformer(output_distribution='normal')
qtdata = quantile.fit_transform(data)
plt.hist(qtdata, bins=25)
plt.show()

# %%
sns.distplot(qtdata, bins=20);
# Out:
# /Users/rezamosavi/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### power transformer

# %%
pt = PowerTransformer()
pdata = pt.fit_transform(data)
plt.hist(pdata, bins=25)
plt.show()

# %%
sns.distplot(pdata, bins=20);
# Out:
# /Users/rezamosavi/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### min-max-transformer

# %%
min_max = MinMaxScaler()
min_max_data = min_max.fit_transform(data)
plt.hist(min_max_data, bins=25)
plt.show()

# %%
sns.distplot(min_max_data, bins=20);
# Out:
# /Users/rezamosavi/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### RobustScaler

# %%
r_scaler = RobustScaler()
r_data = r_scaler.fit_transform(data)
plt.hist(r_data, bins=25)
plt.show()

# %%
sns.distplot(r_data, bins=20);
# Out:
# /Users/rezamosavi/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
s_scaler  = StandardScaler()
s_data = s_scaler.fit_transform(data)
plt.hist(s_data, bins=25)
plt.show()

# %%
sns.distplot(s_data, bins=20);
# Out:
# /Users/rezamosavi/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Set New Data

# %%
data = pd.DataFrame(qtdata ,columns=Columns)
data
# Out:
#         timedelta   n_tokens_title   n_tokens_content   num_hrefs  \
# 0        5.199338         0.744694          -0.853480   -0.774833
# 1        5.199338        -0.633317          -0.650274   -1.088723
# 2        5.199338        -0.633317          -0.899534   -1.088723
# 3        5.199338        -0.633317           0.301855    0.229064
# 4        5.199338         1.194628           1.264066    1.093272
# ...           ...              ...                ...         ...
# 35098   -5.199338         0.296607          -0.222630    0.229064
# 35099   -5.199338         0.744694          -0.293986    0.229064
# 35100   -5.199338        -0.162552           0.079120    1.381364
# 35101   -5.199338        -2.156675           0.616541    0.356159
# 35102   -5.199338        -0.162552          -1.264066   -1.716415
#
#         num_self_hrefs   num_imgs   num_videos   average_token_length  \
# 0            -0.249721  -0.234219    -5.199338               0.045719
# 1            -0.766391  -0.234219    -5.199338               0.862352
# 2            -0.766391  -0.234219    -5.199338              -0.999847
# 3            -5.199338  -0.234219    -5.199338              -0.962734
# 4             2.256745   1.664082    -5.199338               0.054483
# ...                ...        ...          ...                    ...
# 35098         1.378114  -0.234219     0.705530              -0.521538
# 35099         1.378114   0.636387     3.198563              -0.960227
# 35100        -0.766391   1.202347     0.705530               1.413511
# 35101        -0.766391  -0.234219    -5.199338               1.073102
# 35102        -0.766391  -5.199338     1.295363              -0.714611
#
#         num_keywords   data_channel_is_lifestyle  ...   min_positive_polarity  \
# 0          -1.059682                   -5.199338  ...                0.248427
# 1          -1.634747                   -5.199338  ...               -1.166919
# 2          -0.545244                   -5.199338  ...                0.248427
# 3          -0.074087                   -5.199338  ...                1.014571
# 4          -0.074087                   -5.199338  ...               -1.166919
# ...              ...                         ...  ...                     ...
# 35098       0.353487                   -5.199338  ...                0.248427
# 35099      -0.074087                   -5.199338  ...                1.014571
# 35100       0.353487                   -5.199338  ...                1.014571
# 35101      -1.059682                   -5.199338  ...               -0.345485
# 35102      -1.634747                   -5.199338  ...                0.248427
#
#         max_positive_polarity   avg_negative_polarity   min_negative_polarity  \
# 0                   -0.292676               -0.862544               -0.321611
# 1                   -0.292676                1.304121                1.358913
# 2                    5.199338               -1.664082               -0.879040
# 3                    0.041413               -1.003943               -0.321611
# 4                    5.199338                0.312883                0.020074
# ...                       ...                     ...                     ...
# 35098               -0.162552               -0.076082                0.020074
# 35099               -0.292676                0.403356                0.383024
# 35100               -1.042247               -0.913025               -0.879040
# 35101               -1.042247                0.462991                0.020074
# 35102               -1.042247                0.520661                0.983573
#
#         max_negative_polarity   title_subjectivity   title_sentiment_polarity  \
# 0                   -1.428482             0.702315                  -1.397837
# 1                   -0.128317            -5.199338                  -0.254902
# 2                   -0.853480            -5.199338                  -0.254902
# 3                   -1.128144            -5.199338                  -0.254902
# 4                    0.764710             0.527858                   0.631785
# ...                       ...                  ...                        ...
# 35098               -0.619578            -0.027604                  -0.254902
# 35099               -0.128317             0.190587                   5.199338
# 35100               -1.128144             0.527858                   0.631785
# 35101                1.471555            -5.199338                  -0.254902
# 35102               -1.428482             0.251016                   0.916587
#
#         abs_title_subjectivity   abs_title_sentiment_polarity    shares
# 0                    -5.199338                       0.499230 -1.557075
# 1                     5.199338                      -5.199338 -1.202347
# 2                     5.199338                      -5.199338  0.230353
# 3                     5.199338                      -5.199338 -0.129582
# 4                    -1.255743                       0.350817 -1.851734
# ...                        ...                            ...       ...
# 35098                -0.152391                      -5.199338  0.478025
# 35099                -0.524976                       5.199338  0.546700
# 35100                -1.255743                       0.350817  0.546700
# 35101                 5.199338                      -5.199338 -0.287442
# 35102                -0.639462                       0.699108  0.005018
#
# [35103 rows x 42 columns]

# %%
data.shape
# Out:
# (35103, 42)

# %%
data.describe()
# Out:
#           timedelta   n_tokens_title   n_tokens_content     num_hrefs  \
# count  35103.000000     35103.000000       35103.000000  35103.000000
# mean       0.003918         0.000467          -0.080253     -0.089938
# std        1.018939         0.981936           1.261216      1.287988
# min       -5.199338        -5.199338          -5.199338     -5.199338
# 25%       -0.675277        -0.633317          -0.675277     -0.774833
# 50%        0.001255        -0.162552          -0.001255     -0.075345
# 75%        0.675277         0.744694           0.675277      0.664287
# max        5.199338         5.199338           5.199338      5.199338
#
#         num_self_hrefs      num_imgs    num_videos   average_token_length  \
# count     35103.000000  35103.000000  35103.000000           35103.000000
# mean         -0.490395     -0.619465     -2.976134              -0.080305
# std           2.013621      2.170366      3.001753               1.260992
# min          -5.199338     -5.199338     -5.199338              -5.199338
# 25%          -0.766391     -0.234219     -5.199338              -0.674867
# 50%           0.199538     -0.234219     -5.199338              -0.000378
# 75%           0.583496      0.636387      0.705530               0.674458
# max           5.199338      5.199338      5.199338               5.199338
#
#         num_keywords   data_channel_is_lifestyle  ...   min_positive_polarity  \
# count   35103.000000                35103.000000  ...            35103.000000
# mean        0.620392                   -4.666710  ...               -0.078728
# std         2.170935                    2.292395  ...                1.236799
# min        -5.199338                   -5.199338  ...               -5.199338
# 25%        -0.545244                   -5.199338  ...               -0.608973
# 50%        -0.074087                   -5.199338  ...                0.248427
# 75%         0.751333                   -5.199338  ...                0.248427
# max         5.199338                    5.199338  ...                5.199338
#
#         max_positive_polarity   avg_negative_polarity   min_negative_polarity  \
# count            35103.000000            35103.000000            35103.000000
# mean                 1.453951                0.201811               -0.290063
# std                  2.985462                1.559527                2.387055
# min                 -5.199338               -5.199338               -5.199338
# 25%                 -0.551076               -0.674775               -0.592444
# 50%                  0.041413                0.000022                0.020074
# 75%                  5.199338                0.675304                0.676854
# max                  5.199338                5.199338                5.199338
#
#         max_negative_polarity   title_subjectivity   title_sentiment_polarity  \
# count            35103.000000         35103.000000               35103.000000
# mean                 0.196621            -1.799335                   0.033791
# std                  1.548096             3.329938                   1.115374
# min                 -5.199338            -5.199338                  -5.199338
# 25%                 -0.619578            -5.199338                  -0.254902
# 50%                 -0.128317             0.003764                  -0.254902
# 75%                  0.764710             0.702315                   0.631785
# max                  5.199338             5.199338                   5.199338
#
#         abs_title_subjectivity   abs_title_sentiment_polarity        shares
# count             35103.000000                   35103.000000  35103.000000
# mean                  2.087876                      -2.194107      0.006300
# std                   3.431638                       3.123107      1.024512
# min                  -5.199338                      -5.199338     -5.199338
# 25%                  -0.639462                      -5.199338     -0.673702
# 50%                   5.199338                      -5.199338      0.005018
# 75%                   5.199338                       0.699108      0.676854
# max                   5.199338                       5.199338      5.199338
#
# [8 rows x 42 columns]

# %% [markdown]
# # Train Linear Model

# %%
X = data.drop(columns=[" shares"])
y = data[" shares"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
linearModel = LinearRegression()
linearModel.fit(X_train ,y_train)
# Out:
# LinearRegression()

# %%
Y_pred = linearModel.predict(X_test)

# %%
mean_squared_error(y_test,Y_pred)
# Out:
# 0.9190002530940686

# %%
r2_score(y_test ,Y_pred)
# Out:
# 0.1093843935709794

# %%
X = originData.drop(columns=[" shares"])
y = originData[" shares"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
linearModel.fit(X_train ,y_train)
# Out:
# LinearRegression()

# %%
Y_pred = linearModel.predict(X_test)
mean_squared_error(y_test,Y_pred)
# Out:
# 163042271.47339654

# %%
r2_score(y_test ,Y_pred)
# Out:
# 0.013436911487878178

# %% [markdown]
# ### Ridge and Lasso regression.

# %% [markdown]
# # Polynomial Model

# %%
poly = PolynomialFeatures(degree=2)
poly_features = poly.fit_transform(X)
predict = poly.fit_transform(y.array.reshape(-1, 1))

# %%
X_train, X_test, y_train, y_test = train_test_split(poly_features, predict, test_size=0.33, random_state=42)

# %%
linearModel.fit(X_train ,y_train)
# Out:
# LinearRegression()

# %%
y_pred = linearModel.predict(X_test)

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 1.495794533846027

# %%
r2_score(y_test ,y_pred)
# Out:
# 0.36548444586987316
